# %%
urls = ['https://www.clubmahindra.com/blog/experience/celebrate-rann-utsav-with-club-mahindra' , 'https://www.clubmahindra.com/blog/places-to-visit/4-summer-destinations-to-beat-the-heat']

result = asyncio.run(crawl_batch(urls))

for x in result:
    print(x.keys())
